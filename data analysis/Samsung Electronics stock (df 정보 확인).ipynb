# %%
# 데이터 불러오기

# %%
! conda install pandas-datareader
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
# https://finance.yahoo.com/ 
import pandas as pd 
import numpy as np 
from pandas_datareader import data

# %%
df = data.get_data_yahoo('005930.KS', "2022-01-01")

# %%
# 데이터프레임의 어떤 컬럼이 있는지, 몇 개의 데이터가수집되었는지 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 55 entries, 2022-01-04 to 2022-03-25
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       55 non-null     int64
#  1   Low        55 non-null     int64
#  2   Open       55 non-null     int64
#  3   Close      55 non-null     int64
#  4   Volume     55 non-null     int64
#  5   Adj Close  55 non-null     int64
# dtypes: int64(6)
# memory usage: 3.0 KB

# %%
# 데이터프레임의 평균, 표준편차. 사분위수 등 주요 통계 지표를 확인

# %%
df.describe()
# Out:
#                High           Low          Open         Close        Volume  \
# count     55.000000     55.000000     55.000000     55.000000  5.500000e+01
# mean   74085.454545  73207.272727  73790.909091  73596.363636  1.129958e+07
# std     2967.316919   2800.783921   2998.843773   2887.839359  7.342425e+06
# min    69500.000000  68700.000000  68800.000000  69500.000000  0.000000e+00
# 25%    71100.000000  70350.000000  70750.000000  70600.000000  9.361516e+06
# 50%    74200.000000  73100.000000  74100.000000  73700.000000  1.242742e+07
# 75%    75800.000000  74700.000000  75700.000000  75500.000000  1.432544e+07
# max    79600.000000  78600.000000  79500.000000  78900.000000  3.794336e+07
#
#           Adj Close
# count     55.000000
# mean   73596.363636
# std     2887.839359
# min    69500.000000
# 25%    70600.000000
# 50%    73700.000000
# 75%    75500.000000
# max    78900.000000

# %%
# 종가(Close) 기준 최대값, 최소값, 평균값 구하기

# %%
max(df['Close'])
# Out:
# 78900

# %%
min(df['Close'])
# Out:
# 69500

# %%
df['Close'].mean()
# Out:
# 73596.36363636363

# %%
# 총 데이터 개수 확인 (row 개수)

# %%
df.shape
# Out:
# (55, 6)

# %%
# 특정 칼럼만 선택

# %%
df['Close']
# Out:
# Date
# 2022-01-04    78700
# 2022-01-05    77400
# 2022-01-06    76900
# 2022-01-07    78300
# 2022-01-10    78000
# 2022-01-11    78900
# 2022-01-12    78900
# 2022-01-13    77900
# 2022-01-14    77300
# 2022-01-17    77500
# 2022-01-18    77000
# 2022-01-19    76300
# 2022-01-20    76500
# 2022-01-21    75600
# 2022-01-24    75100
# 2022-01-25    74000
# 2022-01-26    74000
# 2022-01-27    71300
# 2022-01-28    73300
# 2022-02-03    73300
# 2022-02-04    74000
# 2022-02-07    73000
# 2022-02-08    73000
# 2022-02-09    73000
# 2022-02-10    75400
# 2022-02-11    74900
# 2022-02-14    73700
# 2022-02-15    73700
# 2022-02-16    74800
# 2022-02-17    75000
# 2022-02-18    74300
# 2022-02-21    74300
# 2022-02-22    74300
# 2022-02-23    74300
# 2022-02-24    71500
# 2022-02-25    71900
# 2022-02-28    71900
# 2022-03-02    71700
# 2022-03-03    72900
# 2022-03-04    72900
# 2022-03-07    70100
# 2022-03-08    69500
# 2022-03-10    69500
# 2022-03-11    70000
# 2022-03-14    70200
# ...

# %%
# 상위 3개 row 선택

# %%
df[:3]
# Out:
#              High    Low   Open  Close    Volume  Adj Close
# Date
# 2022-01-04  79200  78300  78800  78700  12427416      78700
# 2022-01-05  79000  76400  78800  77400  25470640      77400
# 2022-01-06  77600  76600  76700  76900  12931954      76900

# %%
# 2022년 1월 11 일의 고가CHigh)와 저가(tow) 값 반환

# %%
df.loc['2022-01-11', ['High','Low']]
# Out:
# High    79000
# Low     78000
# Name: 2022-01-11 00:00:00, dtype: int64

# %%
# 데이터를 날짜 역순으로 정렬

# %%
df.sort_index(ascending=False)
# Out:
#              High    Low   Open  Close    Volume  Adj Close
# Date
# 2022-03-25  70200  69600  70100  69800  12892028      69800
# 2022-03-25  70200  69600  70100  69800  12986010      69800
# 2022-03-24  70300  69600  69600  69800  37943357      69800
# 2022-03-23  71200  70300  70600  70500  12398025      70500
# 2022-03-22  70500  69900  69900  70300   9402666      70300
# 2022-03-21  71000  69900  70900  69900  11169002      69900
# 2022-03-18  70900  70200  70600  70700  14410038      70700
# 2022-03-17  70400  70400  70400  70400         0      70400
# 2022-03-16  70500  69700  70200  70400  10175750      70400
# 2022-03-15  70200  70200  70200  70200         0      70200
# 2022-03-14  70200  69600  70000  70200   9040993      70200
# 2022-03-11  70700  69700  70500  70000  15787655      70000
# 2022-03-10  69500  69500  69500  69500         0      69500
# 2022-03-08  70000  68700  68800  69500  15828269      69500
# 2022-03-07  70600  69900  70000  70100  18617138      70100
# ...

# %%
# 결측치가 있는지 확인, 결측치가 있을 경우 결측치 처리

# %%
df.isnull().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64
